# %% [markdown]
# <img src="https://miro.medium.com/1*fq4smdRhVA2ZL6dxrikbKg.jpeg" />

# %% [markdown]
# ## Supervised Learning : is a type of Machine Learning where we have an input variable X and an output variable Y, and we use a Machine Learning algorithm to learn a mapping function from the input X to the output Y.

# %% [markdown]
# ```text
# example:
#
# (X)              (Y)
#  3                4
#
#  8                9
#
#  6                7
#
#
# so y=f(x)=x+1
# ```

# %% [markdown]
# ## mapping function actuallly is a mathematical function which we called ML model which prigdict the output y based on input x

# %% [markdown]
# ## Types of supervised Learning
#
# ```text
#
#         Supervised Learning
#                          │
#              ┌───────────┴───────────┐
#              ↓                       ↓
#        Classification            Regression
#              ↓                       ↓
#        Category/Class          Numerical Value
#              ↓                       ↓
#       Spam / Not Spam          House Price
#       Pass / Fail              Salary
#       Cat / Dog                Temperature
#
# ```

# %% [markdown]
# ## 1)Classification problem
#
# #### Classification problem comes under supervised learning in which we have  input variable X and output variable Y(target variable) is a category or class, and the ML algorithm learns a mapping from input X to one of the predefined class

# %% [markdown]
# # Example1: Spam Email Detection
#
# ```
#    Email	                        Label
#  "You won $1000"	                Spam
#  "Free prize for you"	            Spam
#  "Click here to win"	            Spam
#  "Meeting at 5 PM"	               Not Spam
# "Please send the report"	       Not Spam
#
# ```
#
# <img src="https://miro.medium.com/1*WA9aceQugVlBS81r2a7Snw.png" width="800px"/>

# %% [markdown]
# example-02:cat/dog
#
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20260312160624850278/Classification.webp"/>

# %% [markdown]
# ## conclustion:
# ```
# Historical Emails (X) + Labels (Y)
#                 ↓
#         Classification Algorithm
#                 ↓
#          Learn Patterns
#                 ↓
#           Trained Model
#                 ↓
#        New Email (X)
#                 ↓
#        Prediction: Spam (Y)
# ```

# %% [markdown]
# # Classification:Types

# %% [markdown]
# ## 1)Binary classification(home work)

# %% [markdown]
# ## 2) Multi class Classification (home work)

# %% [markdown]
# ## 3) Multi label Classification (home work)

# %% [markdown]
# ## 4) Imbalanced classification(home work)

# %% [markdown]
# # 2) Regresstion  problem

# %% [markdown]
# ## Regression problem comes  under  supervised learning in which we  have input variable X and output  variable y is continious real value like wight ,sallary

# %% [markdown]
# example:
# ```
# let's suppose there is a marketing company A who does varius advertisement in every year amd get sales on that, below list shows that advertisment made by the company in the last 6 year and the coressponding sales
#
#   Advertisment(INR)       sales(INR)
#     800                      100,000
#     500                      8000
#     900                       12,000
#     1000                      ____
#
# ```
#
# yaha pe kisi particlar advertisment pe jo jo sale hogi wo kisi class ko belong nahi karegi ye ek numercal real values hogi
# that's why it is a regression problem not classfication problem

# %% [markdown]
# ## Regresstion:example
# 1) Determinig market trainds
# 2) house price pridiction
