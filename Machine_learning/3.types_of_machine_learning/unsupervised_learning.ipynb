# %% [markdown]
# # What is unsupervised learning ?

# %% [markdown]
# <img src="https://www.mathworks.com/discovery/unsupervised-learning/_jcr_content/mainParsys/band/mainParsys/lockedsubnav_copy/mainParsys/columns/335ce30a-77fd-4c27-af75-93672733f56b/columns/0e1a10a0-b289-4f36-9928-f1add97647b8/image_2128876021_cop.adapt.full.medium.png/1788512247796.pnghttps://www.mathworks.com/discovery/unsupervised-learning/_jcr_content/mainParsys/band/mainParsys/lockedsubnav_copy/mainParsys/columns/335ce30a-77fd-4c27-af75-93672733f56b/columns/0e1a10a0-b289-4f36-9928-f1add97647b8/image_2128876021_cop.adapt.full.medium.png/1788512247796.png"  width="100%">

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSdOEBntDH_sUudtpl1p9tOKH4RnggxkwUtCLyfRArFmMKPiPFMY6Exw1MK&s=10">

# %% [markdown]
# # unsupervised learning : example

# %% [markdown]
# ## 1) when you goes first time in college or school

# %% [markdown]
# # Unsupervised learning : Types

# %% [markdown]
# ## 1) Clustring
