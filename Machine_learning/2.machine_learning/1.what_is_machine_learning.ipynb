# %% [markdown]
# # what is machine learning ?
#
# # In traditional programming, we explicitly tell the computer what to do by defining the rules in a program
#
# # In Machine Learning, instead of writing every rule manually, we create a computer program or learning algorithm that discovers hidden rules or patterns on its own and and builds a model to make future predictions or decisions on new unseen data set
#
#
#
#
# # please don't afraid from m/c learning algorithm
#
# # it is not a rocket science these m/c learning algorithm is just a program or just a piece of code with involment of some mathematics
#
#
#
#
#
# # as data scientist we don't need to implement the all machine learning algorithm from scratch bcz all these algorith already has been implemented in scikit learn library
