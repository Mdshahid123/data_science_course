# %% [markdown]
# # why we actually Doing programming
#
# ## we doing programming bcz to perform some specific type of task through the computer

# %% [markdown]
# # example:
#
# # let's suppose we have a given sequence below and we have to pridict the output of when input is 4
#
#   X   Y
# # 1 → 1
# # 2 → 4
# # 3 → 9
# # 4 → ?
#
#
#
# # As human we identify the pattern:
#
# # 1 × 1 = 1
# # 2 × 2 = 4
# # 3 × 3 = 9
# # 4 × 4 = 16
#
#
# # pattern/rule
# # Y=f(x)= X^2
#
#
# # we write the programm or logic on the basis of pattern/rule that we have find from the given sequence is

# %%
num = int(input("Enter your number: "))

result = num * num

print(result)
# Out:
# Enter your number:  25
# 625

# %% [markdown]
# # conclustion
# ## In traditinal propgramming we explictly tells the computer what to do
# ## by defining  the  rules in a programm
#
# ## computer program don't need to find a pattern or rule we explicitly defined these rules in a program
#
# ## That is
#
# ```
#  Human finds the pattern/rule
#           ↓
# Human writes the logic/program
#           ↓
# Program applies the rule
#           ↓
#         Output|
#
# ```
