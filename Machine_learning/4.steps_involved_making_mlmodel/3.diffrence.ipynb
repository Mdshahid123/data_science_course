# %% [markdown]
# ## Diffrence b/w eda,data cleaning,feature enginerring and machine learning model
#
#
#
# ```
# EDA asks:
#
# "What is happening in my data?"
#
# Data cleaning asks:
#
# "How should I fix/handle the problems I discovered?"
#
# Feature engineering asks:
#
# "Can I create better features from the existing data?"
#
# Machine Learning asks:
#
# "Can I learn a useful pattern from these features to make predictions?"
# ```
