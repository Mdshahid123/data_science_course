# %%
import pandas as pd 
import seaborn as sbn 
import matplotlib.pyplot as plt

# %%
# read the csv file 
df=pd.read_csv("heart.csv")
print(df)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0     40   M           ATA        140          289          0     Normal    172              N      0.0       Up             0
# 1     49   F           NAP        160          180          0     Normal    156              N      1.0     Flat             1
# 2     37   M           ATA        130          283          0         ST     98              N      0.0       Up             0
# 3     48   F           ASY        138          214          0     Normal    108              Y      1.5     Flat             1
# 4     54   M           NAP        150          195          0     Normal    122              N      0.0       Up             0
# ..   ...  ..           ...        ...          ...        ...        ...    ...            ...      ...      ...           ...
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## step-01 explore the data

# %%
# read the starting rows  
df.head() # top 5 rows
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0   40   M           ATA        140          289          0     Normal    172              N      0.0       Up             0
# 1   49   F           NAP        160          180          0     Normal    156              N      1.0     Flat             1
# 2   37   M           ATA        130          283          0         ST     98              N      0.0       Up             0
# 3   48   F           ASY        138          214          0     Normal    108              Y      1.5     Flat             1

# %%
# read  last 5 rows  

df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913   45   M            TA        110          264          0     Normal    132              N      1.2     Flat             1
# 914   68   M           ASY        144          193          1     Normal    141              N      3.4     Flat             1
# 915   57   M           ASY        130          131          0     Normal    115              Y      1.2     Flat             1
# 916   57   F           ATA        130          236          0        LVH    174              N      0.0     Flat             1
# 917   38   M           NAP        138          175          0     Normal    173              N      0.0       Up             0

# %%
df.sample() # it will give any onw random rows
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 189   53   M           ASY        180          285          0         ST    120              Y      1.5     Flat             1

# %% [markdown]
# ## step-02: understanding the data Structure

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()  # it will give the info like data type and non null values  of all column
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 97.6 KB

# %%
df.describe() # it will give statitical summerry about numerical column
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR     Oldpeak  HeartDisease
# count  918.000000  918.000000   918.000000  918.000000  918.000000  918.000000    918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368    0.887364      0.553377
# std      9.432617   18.514154   109.384145    0.423046   25.460334    1.066570      0.497414
# min     28.000000    0.000000     0.000000    0.000000   60.000000   -2.600000      0.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000    0.000000      0.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000    0.600000      1.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000    1.500000      1.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000    6.200000      1.000000

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='str')

# %% [markdown]
# # finding the quality of data in a data set

# %% [markdown]
# # lets annalyse the whole table

# %%
# find the duplciate rows  (always from the table not from the column )

df.duplicated()  
df.duplicated().sum()


# conclution

# we don't have duplicate rows so that's why we don't need to clean it
# Out:
# np.int64(0)

# %%
# find the null values(missing values) in a table 

# df.isnull()
df.isnull().sum()

# conclustion  
# we don't have null values so we dom't need to hnadle it
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # now we have to analyse the indiviaual columns

# %%
# let's first find the catogrical coulmns and numercail coulmns 
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 97.6 KB

# %% [markdown]
# # catogarical column:sex,ChestPainType ,RestingECG    ,ExerciseAngina,ST_Slope
# # numerical coumns :Age ,RestingBP, Cholesterol ,FastingBS  ,HeartDisease    ,Oldpeak  ,HeartDisease

# %% [markdown]
# # now let's analys the categorical column

# %%
cat_cols=["Sex","ChestPainType" ,"RestingECG" ,"ExerciseAngina","ST_Slope"]
for cat_col in cat_cols:
    print(f"--- Value Counts for {cat_col} ---")
    print(df[cat_col].value_counts())
# Out:
# --- Value Counts for Sex ---
# Sex
# M    725
# F    193
# Name: count, dtype: int64
# --- Value Counts for ChestPainType ---
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64
# --- Value Counts for RestingECG ---
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64
# --- Value Counts for ExerciseAngina ---
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64
# --- Value Counts for ST_Slope ---
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
cat_cols=["Sex","ChestPainType" ,"RestingECG" ,"ExerciseAngina","ST_Slope"]
for cat_col in cat_cols:
    plt.figure(figsize=(6,4))
    sbn.histplot(df[cat_col],kde=True)

# %%
# homw work :what diifffrent kind of analysis we should do in catogrical coulm

# %%
# let's do anaysis on numercial coumns 

#  homw work :what diifffrent kind of analysis we should do in numercal  coulm
