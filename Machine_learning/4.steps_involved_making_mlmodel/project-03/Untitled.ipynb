# %%
import pandas as pd 
import matplotlib.pyplot as mlt 
import seaborn as sbn

# %%
df=pd.read_csv("train.csv")
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1)classifi the dependent and indepndent variable

# %% [markdown]
# ## dependent variable or target column :survived col
# ## independedt variable: pclass(passenger class),sex,age,parch(parent child),fare,embarked(bandargah)

# %% [markdown]
# # 2) classifi the numerical column and categorical column

# %% [markdown]
# # Numerical col:age,fare

# %% [markdown]
# # 3)Univarient analysis:we analyse each col one by one

# %% [markdown]
# ## 1) Age

# %%
df['Age'].describe() # statistical summary
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
mlt.figure(figsize=(6,4))
sbn.histplot(x=df['Age'],kde=True) # by default x axis
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
mlt.figure(figsize=(6,4))
sbn.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df[df['Age']>65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
(df['Age'].isnull().sum()/len(df['Age']))*100
# Out:
# np.float64(19.865319865319865)

# %% [markdown]
# # conclustion
#
# # we have outlier in a age col but these outlier is a genuine outlier
# # we have null values so we have to handle it
# # it is almost normally ditrbuted

# %% [markdown]
# # 2) Fare col

# %%
df['Fare'].describe() # statistical summary
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
mlt.figure(figsize=(6,4))
sbn.histplot(x=df['Fare'],kde=True) # by default x axis
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
mlt.figure(figsize=(6,4))
sbn.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df[df['Fare']>100]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # conclustion
# # fare column is actually contain group fair not indivisual fare so basically it is a valid outlier
# # it is right(postive) skewed
# # there is no missing values

# %%
2) univarient analysis on categorical n
