# %%
import pandas as pd 
import matplotlib.pyplot as mlt 
import seaborn as sbn

# %%
df=pd.read_csv("train.csv")
print(df)
# Out:
#      PassengerId  Survived  Pclass                                               Name     Sex  ...  Parch            Ticket     Fare Cabin  Embarked
# 0              1         0       3                            Braund, Mr. Owen Harris    male  ...      0         A/5 21171   7.2500   NaN         S
# 1              2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...      0          PC 17599  71.2833   C85         C
# 2              3         1       3                             Heikkinen, Miss. Laina  female  ...      0  STON/O2. 3101282   7.9250   NaN         S
# 3              4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...      0            113803  53.1000  C123         S
# 4              5         0       3                           Allen, Mr. William Henry    male  ...      0            373450   8.0500   NaN         S
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass                                               Name     Sex  ...  Parch            Ticket     Fare Cabin  Embarked
# 0            1         0       3                            Braund, Mr. Owen Harris    male  ...      0         A/5 21171   7.2500   NaN         S
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...      0          PC 17599  71.2833   C85         C
# 2            3         1       3                             Heikkinen, Miss. Laina  female  ...      0  STON/O2. 3101282   7.9250   NaN         S
# 3            4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...      0            113803  53.1000  C123         S
# 4            5         0       3                           Allen, Mr. William Henry    male  ...      0            373450   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name     Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886          887         0       2                     Montvila, Rev. Juozas    male  27.0      0      0      211536  13.00   NaN        S
# 887          888         1       1              Graham, Miss. Margaret Edith  female  19.0      0      0      112053  30.00   B42        S
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889          890         1       1                     Behr, Mr. Karl Howell    male  26.0      0      0      111369  30.00  C148        C
# 890          891         0       3                       Dooley, Mr. Patrick    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# servived is a target variable or coulmn or fetures and rest all are the indendent variable on which taget variable depends 
# using these independent vairabvle we have to pridict the output of a dependent or tagrget variavle

# %%
# let's find  the those  features or column  from indepndent vraible which do not effect the target variable 

# we can remove the Passenger ID,name,ticket

# %%
# let's find the  numerical coulmn ,categorical column and mix column 

# numercal coulmn:AGE,Fare
# categorical column:survived,sex

# %% [markdown]
# # Lets' do univarent analysysis

# %% [markdown]
# ## 1) On Numercal column

# %% [markdown]
# ### a) Age

# %%
# statistical summary
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
# plot histogram 
mlt.figure(figsize=(6,4))
sbn.histplot(df["Age"],kde=True) # by default age will at x axis
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# let's make box plot to see the outlier  

mlt.figure(figsize=(6,4))
sbn.boxplot(x=df['Age'])

# if there is any outliers then check it is genuine outlier  or it is arises due to the some problem
# Out:
# <Axes: xlabel='Age'>

# %%
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name   Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33            34         0       2                 Wheadon, Mr. Edward H  male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96            97         0       1             Goldschmidt, Mr. George B  male  71.0      0      0    PC 17754  34.6542    A5        C
# 116          117         0       3                  Connors, Mr. Patrick  male  70.5      0      0      370369   7.7500   NaN        Q
# 493          494         0       1               Artagaveytia, Mr. Ramon  male  71.0      0      0    PC 17609  49.5042   NaN        C
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson  male  80.0      0      0       27042  30.0000   A23        S
# 672          673         0       2           Mitchell, Mr. Henry Michael  male  70.0      0      0  C.A. 24580  10.5000   NaN        S
# ...

# %%
# missing values  
(df['Age'].isnull().sum()/len(df['Age']) )*100
# Out:
# np.float64(19.865319865319865)

# %%
#conclustion: 

#age is almost  norammly distributed 
#almost 20% data is missing 
#there are some outlier but these outlier is valid data

# %% [markdown]
# # 2) Fare column

# %%
df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
mlt.figure(figsize=(6,4))
sbn.histplot(df["Fare"],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# box plot 
mlt.figure(figsize=(6,4))
sbn.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
df[df['Fare']>100]
# Out:
#      PassengerId  Survived  Pclass                                               Name     Sex  ...  Parch    Ticket      Fare            Cabin  Embarked
# 27            28         0       1                     Fortune, Mr. Charles Alexander    male  ...      2     19950  263.0000      C23 C25 C27         S
# 31            32         1       1     Spencer, Mrs. William Augustus (Marie Eugenie)  female  ...      0  PC 17569  146.5208              B78         C
# 88            89         1       1                         Fortune, Miss. Mabel Helen  female  ...      2     19950  263.0000      C23 C25 C27         S
# 118          119         0       1                           Baxter, Mr. Quigg Edmond    male  ...      1  PC 17558  247.5208          B58 B60         C
# 195          196         1       1                               Lurette, Miss. Elise  female  ...      0  PC 17569  146.5208              B80         C
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# np.int64(0)

# %%
## conclustion 

# data is highly(positive) skewed
# fare column is actually contain group fair not indivisual fare 
# we need to do feature enginerring that is we have to create a new col called indivisual fare 
# there is a oulier but it is not a geniune outlier

# %% [markdown]
# # univarient analysis on categorical column

# %% [markdown]
# # 1)Survived col

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
mlt.figure(figsize=(6,4))
sbn.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%1.1f%%',figsize=(6, 6))
# Out:
# <Axes: >

# %%
df['Survived'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 2) pclass col

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
mlt.figure(figsize=(6,4))
sbn.countplot(x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%1.1f%%',figsize=(6, 6))
# Out:
# <Axes: >

# %%
df['Pclass'].isnull().sum()
# Out:
# np.int64(0)

# %%
# conlustion 
# just for curiosity why upper class passenger is more than middle class passenger

# %% [markdown]
# # 3) parch col

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
mlt.figure(figsize=(6,4))
sbn.countplot(x=df['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
df['Parch'].value_counts().plot(kind='pie', autopct='%1.1f%%',figsize=(6, 6))
# Out:
# <Axes: >

# %%
df['Parch'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # sibsp col

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
mlt.figure(figsize=(6,4))
sbn.countplot(x=df['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
df['SibSp'].value_counts().plot(kind='pie', autopct='%1.1f%%',figsize=(6, 6))
# Out:
# <Axes: >

# %%
df['SibSp'].isnull().sum()
# Out:
# np.int64(0)

# %%
# conclustion 
# as sibsp and parch col both measure the family member so we can group together and make a one col called family_size
