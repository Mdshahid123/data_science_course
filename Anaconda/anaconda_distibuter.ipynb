# %% [markdown]
# ## what is anaconda distibuter

# %% [markdown]
# #### Anconda distributer is a software that act as a run time environment for our python propgram
#
# ## It provide a python interpreter(it run your code) , code editor(like vscode,spyter,jupter notebook,jupyter lab),Pre-installed Packages:(It comes with over 600 popular data science libraries, including NumPy, Pandas, Scikit-Learn, and Matplotlib) and apart from this it provide tools like conda

# %% [markdown]
# ## what is conda
#
# ## conda is tools that comes with anconda distibuter and it's job is to manage a envirnoment and packakeges
