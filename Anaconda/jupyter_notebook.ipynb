# %% [markdown]
# ## What is jupyter note book ?
#
# #### Jupyter Notebook is an interactive devlopment  environment where you write python code  and run code in cells.
#
#
# JupyterNote book
# │
# ├── 📓 Notebook (.ipynb)
#      └── Write & run Python cell-by-cell

# %% [markdown]
# #### How to open the jupyter note book
#
# ### method-01 using anaconda prompt
#
# ### -- open anaconda prompt and navigate to the project directory with which you want to work
#
# #### -- and write the command "jupyter notebook" it will be open the jupyter notebook in browser
#
#
# ### method-02 using anaconda navigator
#
# ### -- serach anaconda navigator in window serbar and open  it
#
# ### -- it will open the intractive interface from where you can launch it
